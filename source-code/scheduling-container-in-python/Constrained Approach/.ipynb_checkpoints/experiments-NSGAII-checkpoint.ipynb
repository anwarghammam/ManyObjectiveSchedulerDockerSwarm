# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Nov  2 13:38:02 2021

@author: anwar
"""


from jmetal.algorithm.multiobjective.nsgaiii import UniformReferenceDirectionFactory
from Problem.NSGAII import NSGAII
from jmetal.operator import PolynomialMutation
from jmetal.algorithm.singleobjective.evolution_strategy import EvolutionStrategy
from jmetal.algorithm.multiobjective.ibea import IBEA
from jmetal.operator.crossover import IntegerSBXCrossover
from jmetal.operator.mutation import IntegerPolynomialMutation
from jmetal.operator import BitFlipMutation
from Problem.problem import ReschedulingProblem
from Problem.monoproblem import MonoProblem
from jmetal.algorithm.multiobjective.random_search import RandomSearch
from jmetal.algorithm.singleobjective.local_search import LocalSearch
from jmetal.util.termination_criterion import StoppingByEvaluations
from jmetal.util.solution import get_non_dominated_solutions, print_function_values_to_file,print_variables_to_file,print_function_values_to_screen,print_variables_to_screen
from jmetal.lab.visualization import Plot
from jmetal.core.quality_indicator import QualityIndicator,FitnessValue,HyperVolume,InvertedGenerationalDistance
from jmetal.util.observer import  ProgressBarObserver
import numpy as np
from instance.Instance import Instance
from extract_data import Data
import subprocess
import time
from Problem.Instance_from_Json import createInstance



solutions=[]
all2=np.zeros([1,5])
all3=[]
max_evaluations=2500


def transform(instance):

    problem1=MonoProblem(instance)
    problem=ReschedulingProblem(instance)
    algorithm2 = NSGAII(
        problem=problem,
        population_size=200,
        offspring_population_size=100,
        mutation=BitFlipMutation(probability=0.5),
        crossover=SPXCrossover(probability=0.8),
        termination_criterion=StoppingByEvaluations(max_evaluations=2500)
    )

   
  

    #algorithm1 = RandomSearch(
    
    
    #problem=problem1,
       
        #termination_criterion=StoppingByEvaluations(max_evaluations=max_evaluations)
    #)



    print()
    
    print()
    print()
    
    print()

    print()

    print()



    print()
   

    print()

    print()
    


    print()

    print()
  
    print()
    algorithm2.observable.register(ProgressBarObserver(max=max_evaluations))
    print()
    print()
    print("Algorithm running....")
    print()
    print()
    start_time = time.time()
    #algorithm1.run()
    algorithm2.run()


    print()
    front=algorithm2.get_result()


    #front= get_non_dominated_solutions(algorithm1.get_result())
    violated=0


    front_sol1=[]
    front_sol2=[]
    resultat=[]
    resultat2=[]
    weights=[]

    for ob in instance.objectives:

        for key,value in enumerate((ob)):
            weights.append(ob[value])

    for solution in front:
        
        res=0
        for i,ob in enumerate(solution.objectives):

            res=weights[i]*ob

        resultat.append(res)
        front_sol1.append(solution.objectives)
    best_sol=resultat.index(min(resultat))
    candidate=(front[best_sol])

    print()
    print()

    #print("the 1 candidate solution is :",  candidate)
    print("the local search candidate solution is :",  candidate)
    print()




    #print_function_values_to_file(front,r"/home/anwar/Desktop/NSGAIII/test/&-"+str(max_evaluations)+".txt")
    # print_variables_to_file(front, r"/home/anwar/Desktop/NSGAIII/pareto-front-approach1.txt")
    # #print("functions value of the front :")
    # print()
    # print()
    # print(f'Computing time: ${algorithm1.total_computing_time}')
    #print_function_values_to_screen(front)
    print()
    #print("variables value of the front:")
    print()
    print()
    #cmd = ('docker-machine ssh s1 docker stack deploy --compose-file test.yml p1 ').split()

    #p = subprocess.Popen(cmd)
    #output, errors = p.communicate()

        #print_variables_to_screen(front)


#    plot_front = Plot(title='Pareto front approximation', axis_labels=['nb_nodes','max_containers/node','cohesion','coupling','changes'])
#    plot_front.plot(front, label='NSGAIII-MOOC', filename=r"C:\Users\User\Desktop\MOOC\NSGAIII\MOOC", format='png')


    # for i in all3:
    #     print(i.variables)
    #     print("objectives")
    #

    # state=all3[0].variables
    # candidate_functions=all3[0].objectives
    # print("candidate solution : ")
    # print()

    # print(state)
    # print(candidate_functions)

    

    #Data().updateDockerCompose(instance.containers,instance.images,instance.currentState,instance.nodes,'DockerComposeFiles/initial-docker-compose.yml')

    services_to_shutdown=Data().updateDockerCompose(instance.containers,instance.images,candidate.variables,instance.nodes,'DockerComposeFiles/updated-docker-compose.yml')
    #print(services_to_shutdown)
    #for service in services_to_shutdown:
      #  print(service)
      #  print("docker-machine ssh manager docker service rm " +str(service))
       # cmd = ("docker-machine ssh manager docker service rm "  +str(service)).split()

       # p = subprocess.Popen(cmd)
       # output, errors = p.communicate()
    print(f'Computing time: ${algorithm2.total_computing_time}')
    
    end_time = time.time()
    print(end_time-start_time)
    return algorithm2.total_computing_time
# #-----------------------------------------------------------------------------------------------------------------------------------------------
instance=Instance()
Instance=createInstance(instance)
transform(Instance)
# Out:
# ['p_db2.1.churf312f5anwvh09f6nz56oc', 'p_redis.1.wei6ufbngodhkmm4r2k7zzgti', 'p_redis8.1.lwq7c636dtmwp0n69va5h3epx', 'p_grafana2.1.iist4faew4t3l3v6izjxmp2qv', 'p_db7.1.jqojt77kcsofphkst0p41jr8h', 'p_wordpress3.1.s7rkb92d6u23qu43k25yi7rwi', 'p_db8.1.x0brtcnduef1qw7wj00is1vaq', 'p_wordpress7.1.oxxdu4yr74iat6nf28wi46m9j', 'p_creator.1.vgnuur6krz7fppq2731fforo4', 'p_grafana0.1.k4wduaytbbtdlvrhmqr57y1nv', 'p_db5.1.i3ofw6a0rxjpdyfxfhof2xlsu', 'p_db6.1.ufps71lb703vvb34uyphmf8tm', 'p_rabbitmq1.1.9qmugnu6b6b7c8sfjdbbjheme', 'p_redis9.1.0h52uu2pb0caw532vdc0s5fyt', 'p_redis7.1.xxth2t3696ddmg52xrb6ekut7', 'p_wordpress6.1.wgjfufvfzn8o3gryjaonzjy5j', 'p_prometheus.1.irphro1bmqms0ebsxj904gnm6', 'p_wordpress4.1.wypsc2u8e6cif662st2586a63', 'p_node-exporter.qbemsb8pklax35xdwr740go85.spx4gtqk2m257xae382jucvoo', 'p_cadvisor.qbemsb8pklax35xdwr740go85.cxs18zquj4elpx1ttre5wyxoc', 'p_api.1.i8aoq7k36lc1eq96t2zb23uf3', 'p_redis6.1.1thqv2l0hrooy5iou3fm7yq5d', 'p_mongodb.1.dx1lcr98cpgcyymxwji72cx5h', 'p_rabbitmq.1.wcl4pnno20hiz9euw1x43k35i', 'p_visualizer.1.10xdf19a4mo3resadk6bxmso5', 'p_cbeapp.1.a4gyl7k4hhr8226rs2j0yoopr', 'p_redis5.1.ryd9943dxtc38vpb14cadxzsy', 'p_wordpress5.1.4rt6l01qok70sgponitzdf2q3', 'p_cbedbadmin.1.1oofeud24xrftbmbneeps9o38', 'p_wordpress8.1.pmf1czs6cg6k0amksz2wrwa99', 'p_rabbitmq2.1.uc3mmabgh8mq51qvmb05cg5ea', 'p_rabbitmq4.1.makkljsea4l8pafowee2cvujo', 'p_cadvisor.m2n60pksxbb4pgaboc40k38iu.ufk84h6jz014kve7luwuceio1', 'p_node-exporter.m2n60pksxbb4pgaboc40k38iu.sdxrscarvx4v8uf3brfdxuj0i', 'p_db3.1.lwk9s4i4yaki5mvc83r8ahr9x', 'p_db.1.wfr53mt1jkq5lqxng00xe8tel', 'p_db4.1.sxfeot6bm525qko06hw85f48z', 'p_redis1.1.9qaw9nxo9cusf0os3kg2uz655', 'p_wordpress2.1.ftc9gg33rrpt51uwy3r6jvmz9', 'p_haproxy.1.mdmc5halkd8snymy8i2ivxqmc', 'p_cbedb.1.ezvc3hbsrp6xvdmc9szkhn3jw', 'p_mongodb11.1.of91ft7o1ux4c7h6mp2lebvgb', 'p_rabbitmq6.1.n7zoda6qdgzhpetcytloqd7am', 'p_wordpress9.1.50d9n1l615l0kor8ozl5s6a6q', 'p_rabbitmq9.1.jg4gsbzdsidos1i5k1oyiczci', 'p_grafana3.1.ufvdy6d3bjrgt0l05jsxmq7hq', 'p_grafana1.1.shmo29151n80mxyptxalmfdyn', 'p_rabbitmq5.1.3smkjo6i9ed821n5zt920c0hu', 'p_redis2.1.llft497yvp23ktrvmmlm7qdua', 'p_redis13.1.v6mz5iv8628dsy6w6zqwpqp2x', 'p_mongodb1.1.srvy4s4e8o0fiwu6f7nwtdrsz', 'p_grafana4.1.w7j7g1t0u7z25reqk697q7484', 'p_nginx.1.r68v4r84bli26q611cmwf1a9f', 'p_redis10.1.3aw1kq60uder0zl3uppufjykz', 'p_cadvisor.0z9f32jz0sg7124zyup2u82by.jukkmw5znq2gwf3g5iz2ob89n', 'p_node-exporter.0z9f32jz0sg7124zyup2u82by.vifl7j3j4nke4rpp7vx5orxul']
# None
# ['cbedb']
# None
# None
# None
# ['api']
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# [(39, 25), (39, 28), (25, 40), (28, 40), (8, 20)]
# 0
# 1
# 6
# 7
# 8
# 0
# 1
# 6
# 7
# 8
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-379cb9f80888> in <module>
#     202 instance=Instance()
#     203 Instance=createInstance(instance)
# --> 204 transform(Instance)
#     205
#     206
#
# <ipython-input-1-379cb9f80888> in transform(instance)
#      44     problem1=MonoProblem(instance)
#      45     problem=ReschedulingProblem(instance)
# ---> 46     algorithm2 = NSGAII(
#      47         problem=problem,
#      48         population_size=200,
#
# NameError: name 'NSGAII' is not defined
